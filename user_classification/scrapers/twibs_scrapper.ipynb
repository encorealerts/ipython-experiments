# %%
from lxml import html
from lxml import etree
import requests
import re
import time
import csv

def get_tree(url):
    r = requests.get(url)
    content = r.text.encode(r.encoding).decode('utf-8', errors='ignore')
    tree = html.fromstring(content)
    print(url)
    return tree

def fetch_actor_info(item, url):
    subtree = etree.ElementTree(item)

    raw_info = subtree.xpath('//div[contains(concat(" ", normalize-space(@class), " "), " details ")]/a/text()')[0]
    
    try:
        name = re.search("(.*?)\s*\(", raw_info).group(1)
        handle = re.search("(?<=\().[^)]+", raw_info).group(0)
        category = re.sub(r'%20', ' ', re.search("(?<=\?category\=).[^\&]+", url).group(0))
        subcategory = re.sub(r'%20', ' ', re.search("(?<=subCategory\=).+", url).group(0))
        return [name, handle, category, subcategory]
    except AttributeError:
        return None
    

file_name = 'twibs_scrapped_data_%s.csv' % time.strftime("%d_%m_%Y")

urls = ['http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Business',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Company%20blog',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Entertainment',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Fashion%20and%20Apparel',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Food',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Green%20technology',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Health%20and%20Beauty',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Movie',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Music',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=News%20and%20Media',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Parent',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Politics',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Tech',
'http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Travel',
'http://twibs.com/categories.php?category=Business%20Services&subCategory=Angel%20Investing',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Business%20Consulting',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Business%20Events',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Design',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Marketing%20and%20Advertising',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=mobile%20carriers',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Payments',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Personel%20and%20HR%20Consulting',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Printing',
'http://twibs.com/categories.php?category=Business%20Services&subCateogry=Public%20Relations',
'http://twibs.com/categories.php?category=Tech&subCategory=Social%20Network',
'http://twibs.com/categories.php?category=Tech&subCategory=Software',
'http://twibs.com/categories.php?category=Tech&subCategory=Telecom',
'http://twibs.com/categories.php?category=Tech&subCategory=Web%20Design',
'http://twibs.com/categories.php?category=Transportation&subCategory=Automobiles',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Airlines',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Boating',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Destinations',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Hotels',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Ticket%20sales',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Tourism',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Travel%20Agents',
'http://twibs.com/categories.php?category=Travel%20and%20Recreation&subCategory=Venues',
'http://twibs.com/categories.php?category=Web&subCategory=API',
'http://twibs.com/categories.php?category=Web&subCategory=Payment%20Gateway',
'http://twibs.com/categories.php?category=Web&subCategory=Platform',
'http://twibs.com/categories.php?category=Web&subCategory=Programming%20Languages',
'http://twibs.com/categories.php?category=Web&subCategory=Templates',
'http://twibs.com/categories.php?category=Web&subCategory=Website']


for url in urls:
    
    tree = get_tree(url)
    data = []
    items = tree.xpath("//div[@class='user_container']")

    for item in items:
        actor_info = fetch_actor_info(item, url)
        if not actor_info: continue
        data.append(actor_info)
        print(actor_info)

    with open(file_name, 'a', newline='') as fp:
        file = csv.writer(fp, delimiter=',')
        file.writerows(data)
# Out:
# http://twibs.com/categories.php?category=Bloggers%20Services&subCategory=Business
# ['andriisedniev', 'andriisedniev', 'Bloggers Services', 'Business']
# ['danzarrella', 'danzarrella', 'Bloggers Services', 'Business']
# ['Kathy Johnson', 'Kathy_Johnson', 'Bloggers Services', 'Business']
# ['Jaquoneoqhdoqhd', 'Jaquoneoqhdoqhd', 'Bloggers Services', 'Business']
# ['pchaney', 'pchaney', 'Bloggers Services', 'Business']
# ['massrealty', 'massrealty', 'Bloggers Services', 'Business']
# ['insightful_Psy', 'insightful_Psy', 'Bloggers Services', 'Business']
# ['wendroffcpa', 'wendroffcpa', 'Bloggers Services', 'Business']
# ['lornali', 'lornali', 'Bloggers Services', 'Business']
# ['DaveTaylor', 'DaveTaylor', 'Bloggers Services', 'Business']
# ['kathleengage', 'kathleengage', 'Bloggers Services', 'Business']
# ['Business Exchange', 'BWBX', 'Bloggers Services', 'Business']
# ['GEICO', 'GEICO', 'Bloggers Services', 'Business']
# ['donnagunter', 'donnagunter', 'Bloggers Services', 'Business']
# ...
